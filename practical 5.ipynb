# %% [markdown]
# <a href="https://colab.research.google.com/github/shreyakudmethi/Deep-learning/blob/main/practical%205.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

np.random.seed(42)
X = np.random.rand(200, 5, 1)
y = np.random.randint(0, 2, 200)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4

model = Sequential([
    SimpleRNN(16, activation='relu', input_shape=(5,1)),
    Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=30, batch_size=16, validation_split=0.2)
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc*100:.2f}%")

import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('RNN Training Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - accuracy: 0.4752 - loss: 0.6954 - val_accuracy: 0.6562 - val_loss: 0.6603
# Epoch 2/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5008 - loss: 0.6860 - val_accuracy: 0.6562 - val_loss: 0.6629
# Epoch 3/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5469 - loss: 0.6756 - val_accuracy: 0.6562 - val_loss: 0.6659
# Epoch 4/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5035 - loss: 0.6855 - val_accuracy: 0.6562 - val_loss: 0.6695
# Epoch 5/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5760 - loss: 0.6737 - val_accuracy: 0.6562 - val_loss: 0.6712
# Epoch 6/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5574 - loss: 0.6824 - val_accuracy: 0.6250 - val_loss: 0.6738
# Epoch 7/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5806 - loss: 0.6800 - val_accuracy: 0.6250 - val_loss: 0.6749
# Epoch 8/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5958 - loss: 0.6815 - val_accuracy: 0.5312 - val_loss: 0.6776
# Epoch 9/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6567 - loss: 0.6703 - val_accuracy: 0.5312 - val_loss: 0.6786
# Epoch 10/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6469 - loss: 0.6794 - val_accuracy: 0.5000 - val_loss: 0.6795
# Epoch 11/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6261 - loss: 0.6839 - val_accuracy: 0.5000 - val_loss: 0.6798
# Epoch 12/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6218 - loss: 0.6762 - val_accuracy: 0.5312 - val_loss: 0.6772
# Epoch 13/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6796 - loss: 0.6689 - val_accuracy: 0.5000 - val_loss: 0.6785
# Epoch 14/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6783 - loss: 0.6696 - val_accuracy: 0.5000 - val_loss: 0.6772
# Epoch 15/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6009 - loss: 0.6782 - val_accuracy: 0.5000 - val_loss: 0.6766
# Epoch 16/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6422 - loss: 0.6667 - val_accuracy: 0.5000 - val_loss: 0.6767
# Epoch 17/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6804 - loss: 0.6600 - val_accuracy: 0.5000 - val_loss: 0.6778
# Epoch 18/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6090 - loss: 0.6704 - val_accuracy: 0.5000 - val_loss: 0.6794
# Epoch 19/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6315 - loss: 0.6604 - val_accuracy: 0.5312 - val_loss: 0.6732
# Epoch 20/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6867 - loss: 0.6578 - val_accuracy: 0.5625 - val_loss: 0.6693
# Epoch 21/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6736 - loss: 0.6538 - val_accuracy: 0.5625 - val_loss: 0.6718
# Epoch 22/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7054 - loss: 0.6456 - val_accuracy: 0.5625 - val_loss: 0.6734
# Epoch 23/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6962 - loss: 0.6427 - val_accuracy: 0.5312 - val_loss: 0.6714
# Epoch 24/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7315 - loss: 0.6467 - val_accuracy: 0.5625 - val_loss: 0.6734
# Epoch 25/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6288 - loss: 0.6590 - val_accuracy: 0.5625 - val_loss: 0.6716
# Epoch 26/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5763 - loss: 0.6671 - val_accuracy: 0.5625 - val_loss: 0.6635
# Epoch 27/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6522 - loss: 0.6496 - val_accuracy: 0.5625 - val_loss: 0.6677
# Epoch 28/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6425 - loss: 0.6436 - val_accuracy: 0.6250 - val_loss: 0.6731
# Epoch 29/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6742 - loss: 0.6211 - val_accuracy: 0.6250 - val_loss: 0.6760
# Epoch 30/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6884 - loss: 0.6343 - val_accuracy: 0.6250 - val_loss: 0.6680
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6792 - loss: 0.6643
# Test Accuracy: 67.50%
